# %% [raw]
# sentence = "The Taj Mahal is an ivory-white marble mausoleum on the south bank of the Yamuna river in the Indian city of Agra. It was commissioned in 1632 by the Mughal emperor, Shah Jahan (reigned from 1628 to 1658), to house the tomb of his favourite wife, Mumtaz Mahal."
#
# """
# Person : Snigdha Kakkar
# Place of Birth: India
# Date: 03-04-2024
# Time: 9:30 am
# Money: 100K dollars
# Organization: Amazon, IBM, Stratforce Inc., AccelerateAICareers
# Percent: 30%, 0.5 percent
# """

# %%
sentence = "The Taj Mahal is an ivory-white marble mausoleum on the south bank of the Yamuna river in the Indian city of Agra. It was commissioned in 1632 by the Mughal emperor, Shah Jahan (reigned from 1628 to 1658), to house the tomb of his favourite wife, Mumtaz Mahal."

# %%
import nltk
words = nltk.word_tokenize(sentence)

# %%
words
# Out:
# ['The',
#  'Taj',
#  'Mahal',
#  'is',
#  'an',
#  'ivory-white',
#  'marble',
#  'mausoleum',
#  'on',
#  'the',
#  'south',
#  'bank',
#  'of',
#  'the',
#  'Yamuna',
#  'river',
#  'in',
#  'the',
#  'Indian',
#  'city',
#  'of',
#  'Agra',
#  '.',
#  'It',
#  'was',
#  'commissioned',
#  'in',
#  '1632',
#  'by',
#  'the',
#  'Mughal',
#  'emperor',
#  ',',
#  'Shah',
#  'Jahan',
#  '(',
#  'reigned',
#  'from',
#  '1628',
#  'to',
#  '1658',
#  ')',
#  ',',
#  'to',
#  'house',
#  'the',
#  'tomb',
#  'of',
#  'his',
#  'favourite',
#  'wife',
#  ',',
#  'Mumtaz',
#  'Mahal',
#  '.']

# %%
tag_words = nltk.pos_tag(words)

# %%
tag_words
# Out:
# [('The', 'DT'),
#  ('Taj', 'NNP'),
#  ('Mahal', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('ivory-white', 'JJ'),
#  ('marble', 'NN'),
#  ('mausoleum', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('south', 'JJ'),
#  ('bank', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Yamuna', 'NNP'),
#  ('river', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Agra', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('commissioned', 'VBN'),
#  ('in', 'IN'),
#  ('1632', 'CD'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Mughal', 'NNP'),
#  ('emperor', 'NN'),
#  (',', ','),
#  ('Shah', 'NNP'),
#  ('Jahan', 'NNP'),
#  ('(', '('),
#  ('reigned', 'VBN'),
#  ('from', 'IN'),
#  ('1628', 'CD'),
#  ('to', 'TO'),
#  ('1658', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('to', 'TO'),
#  ('house', 'NN'),
#  ('the', 'DT'),
#  ('tomb', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('favourite', 'JJ'),
#  ('wife', 'NN'),
#  (',', ','),
# ...

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/snigdhakakkar/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/snigdhakakkar/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.ne_chunk(tag_words).draw()

# %% [markdown]
# ![Screen%20Shot%202024-04-03%20at%209.27.35%20AM.png](attachment:Screen%20Shot%202024-04-03%20at%209.27.35%20AM.png)
